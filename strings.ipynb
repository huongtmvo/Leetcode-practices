# %%
with open('/content/huong/data.txt', 'w') as f:
  f.write("hello world\n") 
  f.write("thong le\n")
with open('/content/huong/data.txt', 'r+') as f:
  f.seek(0)
  f.write("huong vo\n")
  f.write("gia le\n")
  f.truncate()
open('/content/huong/data.txt').readlines()
# Out:
# ['huong vo\n', 'gia le\n']

# %%
f1 = open('/content/huong/data.txt')
f1.read().split('\n')
# Out:
# ['hello world', 'thong le']

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.figure(1)
plt.plot([1,1])
plt.figure(2)
plt.plot([1,2])

# %% [markdown]
# # 1. Rotate String
#
# Given two strings s and goal, return true *if and only if* s can become goal after some number of shifts on `s`.
#
# A shift on s consists of moving the leftmost character of s to the rightmost position.
#
# For example, if `s = "abcde"`, then it will be `"bcdea"` after one shift.
#
# Example 1:
# ```
# Input: s = "abcde", goal = "cdeab"
# Output: true
# ```
#
# Example 2:
# ```
# Input: s = "abcde", goal = "abced"
# Output: false
# ```

# %%
def rotateString(s: str, goal: str) -> bool:
  i = 0
  while i <len(s):
    if s == goal:
      return True
    else: 
      s = s[1:] + s[0]
    i = i +1
  return False
  
def rotateString(s: str, goal: str) -> bool:
        if len(goal) != len(s):
            return False
        return goal in s+s

# %%
s = "abcde"; goal = "cdeab"
rotateString(s,goal)
# Out:
# True

# %%
x = 'huong'
x = [1,2,3]
x[3:]
# Out:
# []

# %%
s = "clrwmpkwru" 
goal = "wmpkwruclr"
rotateString(s,goal)
# Out:
# True

# %%
string = 'abcde' 
string = string + string[0]
print(string)

text = "I like Python"
t = text.replace("Python", "Java")
print(t)
# Out:
# abcdea
# I like Java

# %%
string = "abcde"
string = string.replace(string[0],'') + string[0]
print(string)
# Out:
# bcdea

# %% [markdown]
# # 2. Most Common Word
#
# Given a string *paragraph* and a string array of the *banned* words banned, return the most frequent word that is not banned. It is **guaranteed** there is **at least one word** that is not banned, and that the answer is **unique**.
#
# The words in *paragraph* are **case-insensitive** and the answer should be returned in **lowercase**.
#
#
# Example 1:
# ```
# Input: paragraph = "Bob hit a ball, the hit BALL flew far after it was hit.", banned = ["hit"]
# Output: "ball"
# Explanation:
# "hit" occurs 3 times, but it is a banned word.
# "ball" occurs twice (and no other word does), so it is the most frequent non-banned word in the paragraph.
# Note that words in the paragraph are not case sensitive,
# that punctuation is ignored (even if adjacent to words, such as "ball,"),
# and that "hit" isn't the answer even though it occurs more because it is banned.
# ```
#
# Example 2:
# ```
# Input: paragraph = "a.", banned = []
# Output: "a"
# ```

# %%
from typing import List
from collections import Counter
def mostCommonWord(paragraph: str, banned: List[str]) -> str:
  paragraph = paragraph.lower()
  paragraph = "".join(u for u in paragraph if u not in ['.',',',':',";","!","?"])
  wordList = paragraph.split(' ', -1)
  counter = Counter(wordList)
  word, count = '', 0
  for key, value in counter.items():
    if key not in banned:
      if value > count:
        word, count = key, value
  return word  

banned = ["hit"]
paragraph = "Bob hit a ball, the hit BALL flew far after it was hit."
mostCommonWord(paragraph,banned)
# Out:
# 'ball'

# %%
paragraph = "a."; banned = []
mostCommonWord(paragraph,banned)
# Out:
# 'a'

# %%
def getWord(w):
  return ''.join(c for c in w if c.isalpha())

def removePunc(w):
  return ''.join(c for c in w.lower() if c.isalpha() or c.isspace())

w = "ball."
getWord(w)
removePunc("Bob hit a ball, the hit BALL flew far after it was hit.")
# Out:
# 'bob hit a ball the hit ball flew far after it was hit'

# %%
paragraph = "Bob hit a ball, the hit BALL flew far after it was hit."
banned = ['hit']
paragraph = paragraph.lower()
paragraph = "".join(u for u in paragraph if u not in ['.',',',':',";","!","?"])
# paragraph = paragraph.replace(",","")
# paragraph = paragraph.replace(".","")
print(paragraph)
wordList = paragraph.split(' ', -1)
counter = Counter(wordList)
print(counter)
max2 = max(counter.values())
print(max2)
for key in counter:
  if key not in banned:
    print(key,counter[key])
# Out:
# bob hit a ball the hit ball flew far after it was hit
# Counter({'hit': 3, 'ball': 2, 'bob': 1, 'a': 1, 'the': 1, 'flew': 1, 'far': 1, 'after': 1, 'it': 1, 'was': 1})
# 3
# bob 1
# a 1
# ball 2
# the 1
# flew 1
# far 1
# after 1
# it 1
# was 1

# %%
Str = ['ball','a','ball','b','car']
counter = Counter(Str)
print(counter)
# Out:
# Counter({'ball': 2, 'a': 1, 'b': 1, 'car': 1})

# %%
s = [1,3,4,4,1]
maxCount = 0
for i in range(len(s)):
  if s[i] == s[i+1]

# %%
max(3,2)
# Out:
# 3

# %% [markdown]
# # 3. Valid Anagram
#
# Given two strings `s` and `t`, return `true` if `t` is an *anagram* of *s*, and `false` otherwise.
#
# Example 1:
# ```
# Input: s = "anagram", t = "nagaram"
# Output: true
# ```
#
# Example 2:
# ```
# Input: s = "rat", t = "car"
# Output: false
# ```

# %%
def isAnagram(s: str, t: str) -> bool:
  n1 = len(s)
  d1 = {}
  for i in range (0, n1):
    if s[i] not in d1:
      d1[s[i]] = 1
    else:
      d1[s[i]] += 1
  print(d1)

  n2 = len(t)
  d2 = {}
  for i in range (0,n2):
    if t[i] not in d2:
      d2[t[i]] = 1
    else:
      d2[t[i]] += 1
  print(d2)

  for i in d1:
    if i not in d2:
      return False
    else:
      if d1[i] != d2[i]:
        return False
  for i in d2:
    if i not in d1:
      return False
    else:
      if d1[i] != d2[i]:
        return False
  return True

# %%
s = "anagram"; t = "nagaram"
isAnagram(s,t)
# Out:
# {'a': 3, 'n': 1, 'g': 1, 'r': 1, 'm': 1}
# {'n': 1, 'a': 3, 'g': 1, 'r': 1, 'm': 1}
# True

# %%
s = 'helen' ; t = 'lenhecdf'
isAnagram(s,t)
# Out:
# {'h': 1, 'e': 2, 'l': 1, 'n': 1}
# {'l': 1, 'e': 2, 'n': 1, 'h': 1, 'c': 1, 'd': 1, 'f': 1}
# False

# %%
s = 'eat' ; t = 'ate'
isAnagram(s,t)
# Out:
# {'e': 1, 'a': 1, 't': 1}
# {'a': 1, 't': 1, 'e': 1}
# True

# %%
from collections import Counter

s = 'eaaaat'
d = Counter(s)
d.values()
d.keys()
d.values()
d.items()

class ADD:
  def add(self):
    return 1 

  def add1(self, num):
    return num + 1

a = ADD()
a.add()
# Out:
# 1

# %%
class Solution:
    def isAnagram(self, s: str, t: str) -> bool:
        countS = Counter(s)
        countT = Counter(t)
        
        if len(countS.keys()) != len(countT.keys()):
            return False
        
        for i in countS:
            if i not in countT or countS[i] != countT[i]:
                return False
        return True

sol = Solution()
sol.isAnagram('aabbcc', 'abcabc')
# Out:
# True

# %%
d = {'r': 1, 'a': 1, 't': 1}
# d.__getitem__('r')
dir(d)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %%
def isAnagram2(s: str, t: str) -> bool:
  ns = len(s) ; list1 = []
  for i in range(ns):
    list1 += s[i]
  list1.sort()
  print(list1)

  nt = len(t) ; list2 = []
  for j in range(nt):
    list2 += t[j]
  list2.sort()
  print(list2)

  if list1 == list2:
    return True
  else:
    return False

# %%
s = 'rat'; t = 'car'
isAnagram2(s,t)
# Out:
# ['a', 'r', 't']
# ['a', 'c', 'r']
# False

# %%
s = 'anagram' ; t = 'naagrma'
isAnagram2(s,t)
# Out:
# ['a', 'a', 'a', 'g', 'm', 'n', 'r']
# ['a', 'a', 'a', 'g', 'm', 'n', 'r']
# True

# %% [markdown]
# # 4. First Unique Character in a String
#
# Given a string `s`, *find the first non-repeating character in it and return its index*. If it does not exist, return `-1`.
#
# Example 1:
# ```
# Input: s = "leetcode"
# Output: 0
# ```
# Example 2:
# ```
# Input: s = "loveleetcode"
# Output: 2
# ```
# Example 3:
# ```
# Input: s = "aabb"
# Output: -1
# ```

# %%
def firstUniqChar(s: str) -> int:
  n = len(s)
  for i in range (0,n):
    if s[i] not in (s[0:i] + s[i+1:n]):
      return i
  return -1

# %%
from collections import Counter
class Solution:
  def firstUniqChar(self, s: str) -> int:
    counter = Counter(s)
    for i, c in enumerate(s):
      if counter[c] == 1:
        return i
    return -1

# %%
s = "aabb"
Solution().firstUniqChar(s)
print(list(enumerate(s)))

# to create an object in Class Solution
# sol = Solution()
# Out:
# [(0, 'a'), (1, 'a'), (2, 'b'), (3, 'b')]

# %%
s = "leetcode"
Counter(s)
# Out:
# Counter({'c': 1, 'd': 1, 'e': 3, 'l': 1, 'o': 1, 't': 1})

# %%
s = "loveleetcode"
firstUniqChar(s)
# Out:
# 2

# %%
s = 'helenhuongvo'
firstUniqChar(s)
# Out:
# 2

# %% [markdown]
# # 5. Add Strings
#
# Given two non-negative integers, `num1` and `num2` represented as string, return the sum of `num1` and `num2` as a string.
#
# You must solve the problem without using any built-in library for handling large integers (such as BigInteger). You must also not convert the inputs to integers directly.
#
# Example 1:
# ```
# Input: num1 = "11", num2 = "123"
# Output: "134"
# ```
# Example 2:
# ```
# Input: num1 = "456", num2 = "77"
# Output: "533"
# ```
# Example 3:
# ```
# Input: num1 = "0", num2 = "0"
# Output: "0"
# ```

# %%
##RECHECK THE SOLUTIONS.SOMETHING IS WRONG

# %%
def addStrings(num1: str, num2: str) -> str: 
  num1 = num1[::-1]  # reverse a string (a list)
  num2 = num2[::-1]  # reserse a string (a list)
  n = min(len(num1), len(num2))
  carry = 0
  result = []
  for i in range(n):
    s = carry + int(num1[i]) + int(num2[i])
    if s > 10:
      carry = 1
    result.append(str(s%10))
  if len(num1) > len(num2):
    res = num1[n:]
  else: 
    res = num2[n:]
  for c in res:
    s = carry + int(c)
    if s > 10:
      carry = 1
    result.append(str(s%10))
  if carry > 0:
    result.append(str(carry))
  return ''.join(result)[::-1]

# %%
def addStrings2(num1: str, num2: str) -> str: 
  n = max(len(num1), len(num2))
  print(n)
  num1, num2 = num1.zfill(n)[::-1], num2.zfill(n)[::-1]
  carry = 0
  # out = ''
  out = []
  for i in range(n):
    s = carry + int(num1[i]) + int(num2[i])
    carry = s / 10
    out.append(str(s%10))
    # out += str(s%10) not efficient O(n^2)
  if carry > 0:
    out.append(str(carry))
    # out += str(carry)
  return "".join(out)[::-1]

# %%
num1 = "456"; num2 = "77"
addStrings2(num1,num2)
# Out:
# 3
# '335.033.57000000000000003.33'

# %%
'23432'.zfill(10)
# Out:
# '0000023432'

# %%
'23432' + '0' * 5
# Out:
# '2343200000'

# %% [markdown]
# # 6. Roman to Integer
#
# Roman numerals are represented by seven different symbols: `I, V, X, L, C, D and M.`
# ```
# Symbol       Value
# I             1
# V             5
# X             10
# L             50
# C             100
# D             500
# M             1000
# ```
# For example, `2` is written as `II` in Roman numeral, just two one's added together. `12` is written as `XII`, which is simply `X + II`. The number `27` is written as `XXVII`, which is `XX + V + II.`
#
# Roman numerals are usually written largest to smallest from left to right. However, the numeral for four is not `IIII`. Instead, the number four is written as `IV`. Because the one is before the five we subtract it making four. The same principle applies to the number nine, which is written as `IX`. There are six instances where subtraction is used:
#
# - `I` can be placed before `V` (5) and `X` (10) to make 4 and 9.
# - `X` can be placed before `L` (50) and `C` (100) to make 40 and 90.
# - `C` can be placed before `D` (500) and `M` (1000) to make 400 and 900.
# Given a roman numeral, convert it to an integer.
#
# Example 1:
# ```
# Input: s = "III"
# Output: 3
# ```
# Example 2:
# ```
# Input: s = "IV"
# Output: 4
# ```
# Example 3:
# ```
# Input: s = "IX"
# Output: 9
# ```
# Example 4:
# ```
# Input: s = "LVIII"
# Output: 58
# Explanation: L = 50, V= 5, III = 3.
# ```
# Example 5:
# ```
# Input: s = "MCMXCIV"
# Output: 1994
# Explanation: M = 1000, CM = 900, XC = 90 and IV = 4.
# ```

# %%
def romanToInt(s: str) -> int:
  r2d = {'I': 1, 'V': 5, 'X': 10, 'L': 50, 'C': 100, 'D': 500, 'M': 1000}
  n = len(s)
  i = 0
  ans = 0
  while i < n:
    if i+1 < n and r2d[s[i+1]] > r2d[s[i]]:
        ans += r2d[s[i+1]] - r2d[s[i]]
        i += 2
    else:
        ans += r2d[s[i]]
        i += 1
  return ans

# %%
romanToInt("IX")
# Out:
# 9

# %% [markdown]
# # 7. Implement strStr()
#
# Implement `strStr()`.
#
# Return the index of the first occurrence of needle in haystack, or `-1` if `needle` is not part of `haystack`.
#
# **Clarification**:
#
# What should we return when `needle` is an empty string? This is a great question to ask during an interview.
#
# For the purpose of this problem, we will return 0 when `needle` is an empty string. This is consistent to C's `strstr()` and Java's `indexOf().`
#
# Example 1:
# ```
# Input: haystack = "hello", needle = "ll"
# Output: 2
# ```
# Example 2:
# ```
# Input: haystack = "aaaaa", needle = "bba"
# Output: -1
# ```
# Example 3:
# ```
# Input: haystack = "", needle = ""
# Output: 0
# ```

# %%
def strStr(haystack: str, needle: str) -> int:
  if needle =="":
    return 0
  if needle not in haystack:  # abcabcabcabc  abd
    return -1
  else:
    return haystack.index(needle)

# %%
haystack = "hello"; needle = "ll"
strStr(haystack,needle)
# Out:
# 2

# %%
haystack = "aaaaa"; needle = "bba"
strStr(haystack,needle)
# Out:
# -1

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
help(str)

# %% [markdown]
# # 8. [Add Binary](https://leetcode.com/problems/add-binary/)
# Given two binary strings `a` and `b`, return *their sum as a binary string*.
#
# Example 1:
# ```
# Input: a = "11", b = "1"
# Output: "100"
# ```
# Example 2:
# ```
# Input: a = "1010", b = "1011"
# Output: "10101"
# ```

# %%
def addBinary(a: str, b: str) -> str:
  n = max(len(a), len(b))
  a, b = a.zfill(n)[::-1], b.zfill(n)[::-1]
  carry = 0
  out = []
  for i in range(n):
    s = carry + int(a[i]) + int(b[i])
    carry = s//2
    out.append(str(s%2))
  if carry > 0:
    out.append(str(carry))
  return "".join(out)[::-1]

# %%
a = "11"; b = "1"
addBinary(a,b)
# Out:
# '100'

# %%
num1 = '1010'; num2 = '11'
addBinary(num1,num2)
# Out:
# '1101'

# %%
a = "1010101010101010"; b = "11111111111"
addBinary(a,b)
int(a, 2) + int(b, 2)
# Out:
# '1011001010101001'

# %%
bin(int(a, 2) + int(b, 2))
# Out:
# '0b1011001010101001'

# %%
c = "101"
c.zfill(10)[::-1]
# Out:
# '1010000000'

# %% [markdown]
# # 9. Analyze Text:
# Write a class Analyzed Text, which has the following methods:
# - Constructor: Take argument "text", make it lowercase and remove all punctuations. Assume only the following punctuations are used: period(.),exclamation mark (!), comma (,),question mark (?). Store the argument in "fmtText".
# - freqAll: Returns a dictionary of all unique words in the text along with the number of their occurences.
# - freqOf: Returns the frequencey of the word passed in the argument.

# %%
class AnalyzeText(object):
  def __init__(self,text):
    formattedText = text.replace('.','').replace(',','').replace('!','').replace('?','')
    formattedText = formattedText.lower()
    self.fmtText = formattedText

  def freqAll(self):
    freqMap = {}
    wordList = self.fmtText.split(' ') 
    for word in set(wordList):
      freqMap[word] = wordList.count(word)
    return freqMap

  def freqOf(self,word):
    freqDict = self.freqAll()
    if word in freqDict:
      return freqDict[word]
    else:
      return ("Not in the text")

# %%
text = "I work hard. I love learning. Learning is fun!"
ana = AnalyzeText(text)
print(ana.freqAll())
print(ana.freqOf('i'))
# Out:
# {'fun': 1, 'hard': 1, 'is': 1, 'love': 1, 'i': 2, 'work': 1, 'learning': 2}
# 2

# %%
list1 = [1,2,3,4,4,5]
count4= list1.count(4)
print(count4)
# Out:
# 2

# %% [markdown]
# More:
# - 680 (https://leetcode.com/problems/valid-palindrome-ii/)
# - 541 (https://leetcode.com/problems/reverse-string-ii/)
# -

# %% [markdown]
# # List Comprehension

# %%
a = list(range(0,10))

# %%
even = []
for i in a:
  if i % 2 == 0:
    even.append(i)
even
# Out:
# [0, 2, 4, 6, 8]

# %%
[i for i in a if i%2 == 0]
# Out:
# [0, 2, 4, 6, 8]
